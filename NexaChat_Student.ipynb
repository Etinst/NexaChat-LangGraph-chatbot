# %% [markdown]
# # NexaChat Groq Student Improved Version
# Made by Darshan Nitin Barhate

# %% [markdown]
# This notebook is a short guide for the rewritten Streamlit/LangGraph project. The actual app runs from the `.py` files.

# %%
# %pip install -r requirements.txt

# %% [markdown]
# Run the basic app with `streamlit run streamlit_frontend.py`.
# Run the PDF app with `streamlit run streamlit_rag_frontend.py`.
